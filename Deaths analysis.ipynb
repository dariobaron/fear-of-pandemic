# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os

# %%
network_name = "bianconi-barabasi_10000_5"
os.listdir("output/"+network_name)
# Out:
# ['REACTIONsoften_FEARasyLow_FEEDBACKall',
#  'REACTIONsoften_FEARcorr_FEEDBACKshort',
#  'REACTIONsoften_FEARanticorr_FEEDBACKshortlong',
#  'REACTIONsoften_FEARanticorr_FEEDBACKall',
#  'REACTIONsoften_FEARbi_FEEDBACKshort',
#  'REACTIONsoften_FEARuni_FEEDBACKall',
#  'REACTIONsoften_FEARbi_FEEDBACKnone',
#  'REACTIONcut_FEARfixed_FEEDBACKlong',
#  'REACTIONcut_FEARasyLow_FEEDBACKlong',
#  'REACTIONcut_FEARfixed_FEEDBACKshortlong',
#  'REACTIONsoften_FEARbi_FEEDBACKneighbours',
#  'REACTIONcut_FEARuni_FEEDBACKnone',
#  'REACTIONsoften_FEARasyLow_FEEDBACKneighbours',
#  'REACTIONcut_FEARfixed_FEEDBACKshort',
#  'REACTIONsoften_FEARfixed_FEEDBACKshortlong',
#  'REACTIONsoften_FEARasyLow_FEEDBACKnone',
#  'REACTIONcut_FEARasyHigh_FEEDBACKshortlong',
#  'REACTIONcut_FEARanticorr_FEEDBACKlong',
#  'REACTIONcut_FEARbi_FEEDBACKnone',
#  'REACTIONcut_FEARcorr_FEEDBACKall',
#  'REACTIONcut_FEARbi_FEEDBACKshortlong',
#  'REACTIONcut_FEARbi_FEEDBACKall',
#  'REACTIONsoften_FEARasyHigh_FEEDBACKlong',
#  'REACTIONsoften_FEARasyHigh_FEEDBACKshortlong',
#  'REACTIONsoften_FEARfixed_FEEDBACKlong',
#  'REACTIONcut_FEARuni_FEEDBACKlong',
#  'execution_log.txt',
#  'REACTIONsoften_FEARanticorr_FEEDBACKshort',
#  'REACTIONcut_FEARasyLow_FEEDBACKnone',
#  'REACTIONcut_FEARasyLow_FEEDBACKshortlong',
#  'REACTIONsoften_FEARuni_FEEDBACKlong',
#  'REACTIONsoften_FEARcorr_FEEDBACKlong',
#  'REACTIONsoften_FEARcorr_FEEDBACKall',
#  'REACTIONsoften_FEARfixed_FEEDBACKall',
#  'REACTIONcut_FEARuni_FEEDBACKall',
#  'REACTIONcut_FEARanticorr_FEEDBACKall',
#  'REACTIONsoften_FEARanticorr_FEEDBACKnone',
#  'REACTIONcut_FEARcorr_FEEDBACKshort',
#  'REACTIONsoften_FEARasyHigh_FEEDBACKshort',
#  'REACTIONsoften_FEARcorr_FEEDBACKshortlong',
#  'REACTIONcut_FEARuni_FEEDBACKshortlong',
#  'REACTIONsoften_FEARasyHigh_FEEDBACKneighbours',
#  'REACTIONcut_FEARbi_FEEDBACKshort',
#  'REACTIONsoften_FEARbi_FEEDBACKshortlong',
#  'REACTIONsoften_FEARcorr_FEEDBACKnone',
#  'REACTIONcut_FEARasyLow_FEEDBACKshort',
#  'REACTIONsoften_FEARasyLow_FEEDBACKshortlong',
#  'REACTIONcut_FEARanticorr_FEEDBACKnone',
#  'REACTIONsoften_FEARfixed_FEEDBACKshort',
#  'REACTIONcut_FEARfixed_FEEDBACKneighbours',
#  'REACTIONsoften_FEARuni_FEEDBACKshortlong',
#  'REACTIONsoften_FEARasyLow_FEEDBACKlong',
#  'REACTIONcut_FEARasyHigh_FEEDBACKshort',
#  'REACTIONcut_FEARfixed_FEEDBACKnone',
#  'REACTIONsoften_FEARuni_FEEDBACKshort',
#  'REACTIONcut_FEARanticorr_FEEDBACKshort',
#  'REACTIONcut_FEARanticorr_FEEDBACKshortlong',
#  'REACTIONsoften_FEARasyHigh_FEEDBACKall',
#  'REACTIONcut_FEARasyHigh_FEEDBACKneighbours',
#  'REACTIONsoften_FEARbi_FEEDBACKlong',
#  'REACTIONcut_FEARasyHigh_FEEDBACKlong',
#  'REACTIONsoften_FEARasyHigh_FEEDBACKnone',
#  'REACTIONcut_FEARuni_FEEDBACKshort',
#  'REACTIONsoften_FEARasyLow_FEEDBACKshort',
#  'REACTIONcut_FEARfixed_FEEDBACKall',
#  'REACTIONsoften_FEARfixed_FEEDBACKnone',
#  'REACTIONcut_FEARuni_FEEDBACKneighbours',
#  'REACTIONcut_FEARcorr_FEEDBACKlong',
#  'REACTIONsoften_FEARfixed_FEEDBACKneighbours',
#  'REACTIONsoften_FEARanticorr_FEEDBACKneighbours',
#  'REACTIONcut_FEARasyLow_FEEDBACKall',
#  'REACTIONcut_FEARcorr_FEEDBACKnone',
#  'REACTIONcut_FEARbi_FEEDBACKneighbours',
#  'REACTIONcut_FEARcorr_FEEDBACKshortlong',
#  'REACTIONcut_FEARasyHigh_FEEDBACKall',
#  'REACTIONcut_FEARbi_FEEDBACKlong',
#  'REACTIONsoften_FEARuni_FEEDBACKnone',
#  'REACTIONcut_FEARasyHigh_FEEDBACKnone',
#  'REACTIONsoften_FEARanticorr_FEEDBACKlong',
#  'REACTIONcut_FEARcorr_FEEDBACKneighbours',
#  'REACTIONsoften_FEARcorr_FEEDBACKneighbours',
#  'REACTIONcut_FEARanticorr_FEEDBACKneighbours',
#  'REACTIONcut_FEARasyLow_FEEDBACKneighbours',
#  'REACTIONnone_FEARnone_FEEDBACKnone',
#  'REACTIONsoften_FEARbi_FEEDBACKall',
#  'REACTIONsoften_FEARuni_FEEDBACKneighbours']

# %%
hyper_parameters = ["REACTION","FEAR","FEEDBACK"]
hyper_par_values = [["soften","cut"], ["fixed","uni","asyLow","asyHigh","bi","corr","anticorr"], ["short","long","shortlong","neighbours","all"]]

# %%
hyper_par_values
# Out:
# [['soften', 'cut'],
#  ['fixed', 'uni', 'asyLow', 'asyHigh', 'bi', 'corr', 'anticorr'],
#  ['short', 'long', 'shortlong', 'neighbours', 'all']]

# %%
simulation_name = "_".join([hyper_parameters[i]+hyper_par_values[i][0] for i in range(len(hyper_parameters))])

# %%
simulation_name
# Out:
# 'REACTIONsoften_FEARfixed_FEEDBACKshort'

# %%
simulation_name2 = simulation_name.replace("none","short")

# %%
data_list = []
for i,rea in enumerate(hyper_par_values[0]):
    data_fear = []
    for j,fea in enumerate(hyper_par_values[1]):
        data_feedback = []
        for k,fee in enumerate(hyper_par_values[2]):
            hpv = [rea,fea,fee]
            simulation_name = "_".join([hyper_parameters[i]+hpv[i] for i in range(len(hyper_parameters))])
            df_run = [
                pd.read_csv(os.path.join("output", network_name, simulation_name, str(i)+".txt"),
                            sep=" ", header=0, index_col="t",  dtype={"t":np.float64,"S":"Int32","E":"Int32","I":"Int32","R":"Int32","D":"Int32"})
                for i in range(100)
            ]
            data_feedback.append(pd.concat(df_run, axis=1, join="outer", keys=[i for i in range(100)]))
            print(f"Loading dataset: {(i*7*6+j*6+k)*100//84}%", flush=True, end="\r")
        data_feedback = pd.concat(data_feedback, keys=hyper_par_values[2], copy=False)
        data_fear.append(data_feedback)
    data_fear = pd.concat(data_fear, keys=hyper_par_values[1], copy=False)
    data_list.append(data_fear)
data = pd.concat(data_list, keys=hyper_par_values[0], copy=False)
data.rename_axis(index=["reaction","fear","feedback","t"], inplace=True)

simulation_name_noFeedback = "_".join([hyper_parameters[i]+"none" for i in range(len(hyper_parameters))])
data_none = pd.concat([pd.read_csv(os.path.join("output", network_name, simulation_name, str(i)+".txt"),
                            sep=" ", header=0, index_col="t",  dtype={"t":np.float64,"S":"Int32","E":"Int32","I":"Int32","R":"Int32","D":"Int32"})
                       for i in range(100)
                      ], axis=1, join="outer", keys=[i for i in range(100)])
data_none.index = pd.MultiIndex.from_product([["none"],["none"],["none"],data_none.index], names=["reaction","fear","feedback","t"])

data = pd.concat([data_none,data])

print("Loading dataset: Completed!")
# Out:
# Loading dataset: Completed!

# %%
# Out:
#                                      0                             1         \
#                                       S     E     I     R     D     S     E
# reaction fear     feedback t
# none     none     none     0.000   9998     0     2     0     0  9998     0
#                            0.125   9998     0     2     0     0  9998     0
#                            0.250   9998     0     2     0     0  9998     0
#                            0.375   9998     0     2     0     0  9998     0
#                            0.500   9998     0     2     0     0  9998     0
# ...                                 ...   ...   ...   ...   ...   ...   ...
# cut      anticorr all      91.250  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.375  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.500  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.625  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.750  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#
#                                                      ...    98              \
#                                       I     R     D  ...     S     E     I
# reaction fear     feedback t                         ...
# none     none     none     0.000      2     0     0  ...  9998     0     2
#                            0.125      2     0     0  ...  9998     0     2
#                            0.250      2     0     0  ...  9996     2     1
#                            0.375      2     0     0  ...  9995     3     1
#                            0.500      2     0     0  ...  9995     3     1
# ...                                 ...   ...   ...  ...   ...   ...   ...
# cut      anticorr all      91.250  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#                            91.375  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#                            91.500  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#                            91.625  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#                            91.750  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#
#                                                  99
#                                       R     D     S     E     I     R     D
# reaction fear     feedback t
# none     none     none     0.000      0     0  9998     0     2     0     0
#                            0.125      0     0  9998     0     2     0     0
#                            0.250      1     0  9998     0     2     0     0
#                            0.375      1     0  9998     0     2     0     0
#                            0.500      1     0  9998     0     2     0     0
# ...                                 ...   ...   ...   ...   ...   ...   ...
# cut      anticorr all      91.250  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.375  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.500  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.625  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.750  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#
# [58434 rows x 500 columns]

# %%
data
# Out:
#                                      0                             1         \
#                                       S     E     I     R     D     S     E
# reaction fear     feedback t
# none     none     none     0.000   9998     0     2     0     0  9998     0
#                            0.125   9998     0     2     0     0  9998     0
#                            0.250   9998     0     2     0     0  9998     0
#                            0.375   9998     0     2     0     0  9998     0
#                            0.500   9998     0     2     0     0  9998     0
# ...                                 ...   ...   ...   ...   ...   ...   ...
# cut      anticorr all      91.250  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.375  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.500  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.625  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.750  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#
#                                                      ...    98              \
#                                       I     R     D  ...     S     E     I
# reaction fear     feedback t                         ...
# none     none     none     0.000      2     0     0  ...  9998     0     2
#                            0.125      2     0     0  ...  9998     0     2
#                            0.250      2     0     0  ...  9998     0     1
#                            0.375      2     0     0  ...  9998     0     1
#                            0.500      2     0     0  ...  9998     0     1
# ...                                 ...   ...   ...  ...   ...   ...   ...
# cut      anticorr all      91.250  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#                            91.375  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#                            91.500  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#                            91.625  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#                            91.750  <NA>  <NA>  <NA>  ...  <NA>  <NA>  <NA>
#
#                                                  99
#                                       R     D     S     E     I     R     D
# reaction fear     feedback t
# none     none     none     0.000      0     0  9998     0     2     0     0
#                            0.125      0     0  9998     0     2     0     0
#                            0.250      1     0  9998     0     2     0     0
#                            0.375      1     0  9997     1     2     0     0
#                            0.500      1     0  9997     1     2     0     0
# ...                                 ...   ...   ...   ...   ...   ...   ...
# cut      anticorr all      91.250  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.375  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.500  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.625  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#                            91.750  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#
# [58420 rows x 500 columns]

# %%
data.index.names
# Out:
# FrozenList(['reaction', 'fear', 'feedback', 't'])

# %%
data.index
# Out:
# MultiIndex([('none',     'none', 'none',    0.0),
#             ('none',     'none', 'none',  0.125),
#             ('none',     'none', 'none',   0.25),
#             ('none',     'none', 'none',  0.375),
#             ('none',     'none', 'none',    0.5),
#             ('none',     'none', 'none',  0.625),
#             ('none',     'none', 'none',   0.75),
#             ('none',     'none', 'none',  0.875),
#             ('none',     'none', 'none',    1.0),
#             ('none',     'none', 'none',  1.125),
#             ...
#             ( 'cut', 'anticorr',  'all', 90.625),
#             ( 'cut', 'anticorr',  'all',  90.75),
#             ( 'cut', 'anticorr',  'all', 90.875),
#             ( 'cut', 'anticorr',  'all',   91.0),
#             ( 'cut', 'anticorr',  'all', 91.125),
#             ( 'cut', 'anticorr',  'all',  91.25),
#             ( 'cut', 'anticorr',  'all', 91.375),
#             ( 'cut', 'anticorr',  'all',   91.5),
#             ( 'cut', 'anticorr',  'all', 91.625),
#             ( 'cut', 'anticorr',  'all',  91.75)],
#            names=['reaction', 'fear', 'feedback', 't'], length=58420)

# %%
pd.MultiIndex.from_product(hyper_par_values, names=hyper_parameters)
# Out:
# MultiIndex([('soften',    'fixed',      'short'),
#             ('soften',    'fixed',       'long'),
#             ('soften',    'fixed',  'shortlong'),
#             ('soften',    'fixed', 'neighbours'),
#             ('soften',    'fixed',        'all'),
#             ('soften',      'uni',      'short'),
#             ('soften',      'uni',       'long'),
#             ('soften',      'uni',  'shortlong'),
#             ('soften',      'uni', 'neighbours'),
#             ('soften',      'uni',        'all'),
#             ('soften',   'asyLow',      'short'),
#             ('soften',   'asyLow',       'long'),
#             ('soften',   'asyLow',  'shortlong'),
#             ('soften',   'asyLow', 'neighbours'),
#             ('soften',   'asyLow',        'all'),
#             ('soften',  'asyHigh',      'short'),
#             ('soften',  'asyHigh',       'long'),
#             ('soften',  'asyHigh',  'shortlong'),
#             ('soften',  'asyHigh', 'neighbours'),
#             ('soften',  'asyHigh',        'all'),
#             ('soften',       'bi',      'short'),
#             ('soften',       'bi',       'long'),
#             ('soften',       'bi',  'shortlong'),
#             ('soften',       'bi', 'neighbours'),
#             ('soften',       'bi',        'all'),
#             ('soften',     'corr',      'short'),
#             ('soften',     'corr',       'long'),
#             ('soften',     'corr',  'shortlong'),
#             ('soften',     'corr', 'neighbours'),
#             ('soften',     'corr',        'all'),
#             ('soften', 'anticorr',      'short'),
#             ('soften', 'anticorr',       'long'),
#             ('soften', 'anticorr',  'shortlong'),
#             ('soften', 'anticorr', 'neighbours'),
#             ('soften', 'anticorr',        'all'),
#             (   'cut',    'fixed',      'short'),
#             (   'cut',    'fixed',       'long'),
#             (   'cut',    'fixed',  'shortlong'),
#             (   'cut',    'fixed', 'neighbours'),
#             (   'cut',    'fixed',        'all'),
#             (   'cut',      'uni',      'short'),
#             (   'cut',      'uni',       'long'),
#             (   'cut',      'uni',  'shortlong'),
#             (   'cut',      'uni', 'neighbours'),
#             (   'cut',      'uni',        'all'),
#             (   'cut',   'asyLow',      'short'),
#             (   'cut',   'asyLow',       'long'),
#             (   'cut',   'asyLow',  'shortlong'),
#             (   'cut',   'asyLow', 'neighbours'),
#             (   'cut',   'asyLow',        'all'),
#             (   'cut',  'asyHigh',      'short'),
#             (   'cut',  'asyHigh',       'long'),
#             (   'cut',  'asyHigh',  'shortlong'),
#             (   'cut',  'asyHigh', 'neighbours'),
#             (   'cut',  'asyHigh',        'all'),
#             (   'cut',       'bi',      'short'),
#             (   'cut',       'bi',       'long'),
#             (   'cut',       'bi',  'shortlong'),
#             (   'cut',       'bi', 'neighbours'),
#             (   'cut',       'bi',        'all'),
#             (   'cut',     'corr',      'short'),
#             (   'cut',     'corr',       'long'),
#             (   'cut',     'corr',  'shortlong'),
#             (   'cut',     'corr', 'neighbours'),
#             (   'cut',     'corr',        'all'),
#             (   'cut', 'anticorr',      'short'),
#             (   'cut', 'anticorr',       'long'),
#             (   'cut', 'anticorr',  'shortlong'),
#             (   'cut', 'anticorr', 'neighbours'),
#             (   'cut', 'anticorr',        'all')],
#            names=['REACTION', 'FEAR', 'FEEDBACK'])
